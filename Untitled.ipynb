# %%
import pandas as pd    
import seaborn as sns    
df = pd.read_csv('crop_production.csv')
 
Area = df[(df["Area"] == 100)]
Maharashrtra = df[(df["State_Name"] == "Maharashtra")]
yavatmal = Maharashrtra[(Maharashrtra["District_Name"] == "YAVATMAL")]
print(yavatmal)


sns.lineplot(yavatmal["Area"],yavatmal["Production"])
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 137462  Maharashtra      YAVATMAL       1997  Kharif       Arhar/Tur
# 137463  Maharashtra      YAVATMAL       1997  Kharif           Bajra
# 137464  Maharashtra      YAVATMAL       1997  Kharif            Gram
# 137465  Maharashtra      YAVATMAL       1997  Kharif           Jowar
# 137466  Maharashtra      YAVATMAL       1997  Kharif           Maize
# ...             ...           ...        ...          ...        ...
# 137814  Maharashtra      YAVATMAL       2014  Rabi             Jowar
# 137815  Maharashtra      YAVATMAL       2014  Rabi             Maize
# 137816  Maharashtra      YAVATMAL       2014  Rabi             Wheat
# 137817  Maharashtra      YAVATMAL       2014  Summer       Groundnut
# 137818  Maharashtra      YAVATMAL       2014  Whole Year   Sugarcane
#
#             Area  Production
# 137462  113200.0     78400.0
# 137463    8900.0      3800.0
# 137464   16400.0      5200.0
# ...

# %%
import pandas as pd    
import seaborn as sns    
df = pd.read_csv('crop_production.csv')
 
Area = df[(df["Area"] == 100)]
Maharashrtra = df[(df["State_Name"] == "Maharashtra")]
yavatmal = Maharashrtra[(Maharashrtra["District_Name"] == "YAVATMAL")]
print(yavatmal)

statename = input("Enter state: ")
districtname = input("Enter district: ")

sns.lineplot(yavatmal["Area"],yavatmal["Production"])

# %%
import pandas as pd    
import seaborn as sns    
df = pd.read_csv('crop_production.csv')
 
sns.lineplot(df["Crop_Year"],df["Production"])
df["Crop"].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Rice                 15104
# Maize                13947
# Moong(Green Gram)    10318
# Urad                  9850
# Sesamum               9046
#                      ...
# Litchi                   6
# Coffee                   6
# Apple                    4
# Peach                    4
# Other Dry Fruit          1
# Name: Crop, Length: 124, dtype: int64

# %%
"""
print(filedata.columns)
print(filedata['State_Name'])
print(filedata['State_Name'][0:5])
print(filedata.iloc[0:10])
print(filedata.iloc[9:10])

for index,row in filedata.iterrows():
    print(index,row)

for index,row in filedata.iterrows():
    print(index,row['State_Name'])
    
"""    
#currentState = input("Enter your state: ")
#currentDistrict = input("Enter your district: ")

# %%
import pandas as pd

#read csv file
df = pd.read_csv('crop_production.csv')
crop_variable = input("Enter Crop")
crop_list = df[(df["Crop"] == crop_variable)]
print(crop_list)

district_variable = input("Enter your District")
for x in crop_list:
    if crop_list["District_Name"] == district_variable :
        final_list = crop_list["District_Name"]
print(final_list)
